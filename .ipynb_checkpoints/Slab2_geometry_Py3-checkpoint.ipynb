# %%
import rockhound as rh
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import numpy as np
import xarray as xr

# %%
from rockhound.slab2 import ZONES

# Fetch all Slab2 subduction zones and add them inside a list
subduction_zones = []
for zone in ZONES:
    subduction_zones.append(rh.fetch_slab2(zone))

#merge into global
global_sub_zones = xr.merge([grid for grid in subduction_zones])

# %%
# Get min and max values of the subducting plates' depths
vmax = max([grid.dip.actual_range[1] for grid in subduction_zones])
vmin = min([grid.dip.actual_range[0] for grid in subduction_zones])

# %%
# Plot the depth of each subducting plate inside Slab2 with the same colorscale
plt.figure(figsize=(20, 10))
ax = plt.axes(projection=ccrs.Robinson())
for grid in subduction_zones:
    pc = grid.dip.plot.pcolormesh(
        ax=ax,
        transform=ccrs.PlateCarree(),
        add_colorbar=False,
        vmin=vmin,
        vmax=vmax,
    )
ax.set_title("Slab2: Geometry model for subduction zones")
plt.colorbar(
    pc,
    ax=ax,
    label="Dip (°)",
    pad=0.05,
    aspect=40,
    shrink=0.7,
    orientation="horizontal",
)
ax.set_global()
ax.coastlines()
plt.show()

# %%
# Plot the depth of each subducting plate inside Slab2 with the same colorscale
data_crs = ccrs.Geodetic()
poly_data_crs = ccrs.PlateCarree()
projection = ccrs.Robinson()

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(16,8), subplot_kw={'projection': projection})
ax.set_global()
ax.pcolormesh(subduction_zones[0].dip,
        transform=poly_data_crs)
ax.set_title("Slab2: Geometry model for subduction zones")
#plt.colorbar(pc, ax=ax, label="Dip (°)", pad=0.05, aspect=40, shrink=0.7, orientation="horizontal")
#ax.set_global()
#ax.coastlines()
# Out:
# Text(0.5, 1.0, 'Slab2: Geometry model for subduction zones')

# %%
plt.pcolormesh(global_sub_zones.dip.values)

# %%
global_sub_zones.dip
# Out:
# <xarray.DataArray 'dip' (latitude: 5543, longitude: 8027)>
# array([[nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        ...,
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan],
#        [nan, nan, nan, ..., nan, nan, nan]], dtype=float32)
# Coordinates:
#   * latitude   (latitude) float64 -65.0 -64.95 -64.9 -64.85 ... 67.9 67.95 68.0
#   * longitude  (longitude) float64 8.0 8.05 8.1 8.15 ... 340.9 340.9 340.9 341.0
# Attributes:
#     long_name:     Slab dip
#     actual_range:  [ 0.43645677 70.69203949]
#     units:         degree
