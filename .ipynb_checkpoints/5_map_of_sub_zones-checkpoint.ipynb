# %%
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

#from matplotlib import cm
from cmcrameri import cm

# %%
datadir = '/Users/andrew/Documents/Data/Merdith_sub_zones/'

#some densities
perid_density_g_cm3 = 3.3 #g/cm3
perid_density_g_km3 = perid_density_g_cm3 * 100000**3
perid_density_kg_km3 = perid_density_g_km3 * 1e-3

# %%
with open('%s/subduction_tracks.pickle' % datadir, 'rb') as f:
    tracks = pickle.load(f)

# %%
tracks[0]
# Out:
#          lon        lat      depth  depth_uncertainty        dip  \
# 0  35.074628  35.590646  17.977307          12.568384  14.535742
# 1  35.090723  35.606122  18.001975          12.707047  14.509542
# 2  35.106818  35.621598  18.031609          12.847062  14.482045
# 3  35.122912  35.637074  18.066464          12.986543  14.453585
# 4  35.139007  35.652549  18.108612          13.131764  14.422330
# 5  35.155102  35.668025  18.221149          13.278872  14.429978
# 6  35.171197  35.683501  18.324521          13.371096  14.452942
#
#    cum_distance  slab_section_length  pressure    temp  peridotite  \
# 0      0.000000                  NaN  0.581386  95.761    1.213838
# 1      2.253632             2.253767  0.582184  95.761    1.213838
# 2      4.507263             2.253826  0.583142  95.761    1.213838
# 3      6.760895             2.253901  0.584269  95.761    1.213838
# 4      9.014526             2.254026  0.585633  95.761    1.213838
# 5     11.268158             2.256440  0.589272  95.761    1.213838
# 6     13.521789             2.256001  0.592615  95.761    1.213838
#
#           age        SR  conv_rate sub_zone  sub_time  sub_length  \
# 0  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
# 1  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
# 2  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
# 3  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
# 4  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
# 5  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
# 6  233.603201  1.324396  20.519476   Aegean       2.0    4.924265
#
#    perid_volume
# 0           NaN
# 1     13.471346
# 2     13.471703
# 3     13.472150
# 4     13.472894
# 5     13.487323
# 6     13.484702

# %%
np.mean(tracks[0]['dip'])
# Out:
# 14.469452081285715

# %%
dips = []
perids = []
SRs = []
age = []
conv = []
vals = []
total_sub_vals_per_Ma = []
mean_dip = []
STD_dip = []
for track in tracks:
    tmp_df = track[(track['sub_time'] <= 6)]
                  #&(track['pressure'] > 0.1)
                  #&(track['pressure'] <7)]
    vals.append(tmp_df['perid_volume'].values)
    dips.append(tmp_df['dip'].values)
    perids.append(tmp_df['peridotite'].values*tmp_df['slab_section_length'].values)
    SRs.append(tmp_df['SR'].values)
    age.append(tmp_df['age'].values)
    conv.append(tmp_df['conv_rate'].values)
    
    total_sub_vals_per_Ma.append(np.nansum(tmp_df['peridotite'].values*tmp_df['slab_section_length'].values) \
                                 * 1/(np.max(tmp_df['sub_time'] + 1)))
    mean_dip.append(np.mean(tmp_df['dip']))
    STD_dip.append(np.std(tmp_df['dip']))

# %%
vals = np.concatenate(vals, axis=0)
dips = np.concatenate(dips, axis=0)
perids = np.concatenate(perids, axis=0)
SRs = np.concatenate(SRs, axis=0)
age = np.concatenate(age, axis=0)
conv = np.concatenate(conv, axis=0)


perids = perids[np.logical_not(np.isnan(vals))]
dips = dips[np.logical_not(np.isnan(vals))]
SRs = SRs[np.logical_not(np.isnan(vals))]
age = age[np.logical_not(np.isnan(vals))]
conv = conv[np.logical_not(np.isnan(vals))]
vals = vals[np.logical_not(np.isnan(vals))]

# %%
len(total_sub_vals_per_Ma)
# Out:
# 363

# %%
fig, (ax1, ax2 ,ax3) = plt.subplots(nrows=1, ncols=3,figsize=(12,6))
cax1 = ax1.scatter(mean_dip, STD_dip, c=total_sub_vals_per_Ma)
cax2 = ax2.scatter(mean_dip, total_sub_vals_per_Ma, c=STD_dip)
cax3 = ax3.scatter(total_sub_vals_per_Ma, STD_dip, c=mean_dip)
ax1.set_xlabel('Mean Dip (°)')
ax2.set_xlabel('Mean Dip (°)')
ax3.set_xlabel('Perid area (km2)')
ax1.set_ylabel('STD dip (°)')
ax2.set_ylabel('Perid area (km2)')
ax3.set_ylabel('STD dip (°)')
fig.colorbar(cax1, ax=ax1, label='Perid area (km2)')
fig.colorbar(cax2, ax=ax2, label='STD dip (°)')
fig.colorbar(cax3, ax=ax3, label='Mean Dip (°)')
fig.tight_layout()

# %%
####### correlation coefficient ##########

cov_mat = np.corrcoef(np.vstack((conv, age, dips, SRs, perids)))

lab=['conv', 'age', 'dips','SR','perids']

for i in range(0,5):
    cov_mat[i,i+1::] = 0
plt.figure(figsize=(10,10))
plt.imshow(cov_mat, interpolation="nearest", cmap=cm.fes,clim=[-1,1])
plt.gca().invert_yaxis()
plt.gca().xaxis.tick_top()
plt.xticks(np.arange(0,5),lab, rotation='vertical')
#plt.xticklabels(lab)
plt.yticks(np.arange(0,5),lab)
#plt.yticklabels(lab)
plt.colorbar()
#plt.savefig('covariance.pdf')

plt.show()

# %%
np.flip(cov_mat, axis=0)
# Out:
# array([[-0.13852658,  0.00476385,  0.52321973, -0.41401846,  1.        ],
#        [ 0.18585321,  0.22554359, -0.11351661,  1.        ,  0.        ],
#        [-0.04817077,  0.03076099,  1.        ,  0.        ,  0.        ],
#        [ 0.02125344,  1.        ,  0.        ,  0.        ,  0.        ],
#        [ 1.        ,  0.        ,  0.        ,  0.        ,  0.        ]])

# %%
####### correlation coefficient ##########

cov_mat = np.corrcoef(np.vstack((mean_dip, STD_dip, total_sub_vals_per_Ma)))

lab=['mean dip', 'std dip', 'sub vals']

for i in range(0,3):
    cov_mat[i,i+1::] = 0
plt.figure(figsize=(10,10))
plt.imshow(cov_mat, interpolation="nearest", cmap=cm.fes,clim=[-1,1])
plt.gca().invert_yaxis()
plt.gca().xaxis.tick_top()
plt.xticks(np.arange(0,3),lab, rotation='vertical')
#plt.xticklabels(lab)
plt.yticks(np.arange(0,3),lab)
#plt.yticklabels(lab)
plt.colorbar()
#plt.savefig('covariance.pdf')

plt.show()

# %%
np.flip(cov_mat, axis=0)
# Out:
# array([[0.38015215, 0.40757601, 1.        ],
#        [0.72029342, 1.        , 0.        ],
#        [1.        , 0.        , 0.        ]])

# %%
plt.scatter(SRs[::100], dips[::100], c=perids[::100], cmap=cm.batlow)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(12,6))
hist = ax.hist2d(dips, perids, (20, 20), cmap=cm.batlow)
#ax.set_ylim(0,1000)
ax.set_xlabel('dip (°)', fontsize=20)
ax.set_ylabel('perid (km3)', fontsize=20)
ax.tick_params(axis='both', labelsize=16)

cbar = fig.colorbar(hist[3], ax=ax, orientation='horizontal')
cbar.set_label('Count', fontsize=20)
cbar.ax.tick_params(labelsize=16)

# %%
import rockhound as rh
from rockhound.slab2 import ZONES
#all sections
# Fetch all Slab2 subduction zones and add them inside a list
subduction_zones = []
for zone in ZONES:
    subduction_zones.append(rh.fetch_slab2(zone))

# %%
subduction_zones[0]['dip'].values.ravel()

# %%
all_dips = []
for zone in subduction_zones:
    all_dips.append(zone['dip'].values.ravel())

# %%
all_dips = np.concatenate(all_dips)
all_dips = all_dips[np.logical_not(np.isnan(all_dips))]

# %%
plt.hist(all_dips)
plt.hist(dips)
plt.semilogy()
